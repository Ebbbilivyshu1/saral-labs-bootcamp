# %%
# !apt-get install tesseract-ocr -y
# !pip install pytesseract pillow

import pytesseract
from PIL import Image

img = Image.open('gpt papers sequence.png')
text = pytesseract.image_to_string(img)

print(text)
